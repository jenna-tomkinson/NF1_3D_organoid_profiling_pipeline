# %% [markdown]
# This notebook performs profile normalization.
# All profiles are normalized to the DMSO control treated profiles.

# %%
import argparse
import pathlib
import sys

import numpy as np
import pandas as pd
from pycytominer import normalize

cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd
else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break
sys.path.append(str(root_dir / "utils"))
from arg_parsing_utils import parse_args
from notebook_init_utils import bandicoot_check, init_notebook

root_dir, in_notebook = init_notebook()

profile_base_dir = bandicoot_check(pathlib.Path("~/mnt/bandicoot").resolve(), root_dir)

# %%
if not in_notebook:
    args = parse_args()
    patient = args["patient"]

else:
    patient = "NF0014_T1"

# %%
# pathing
sc_annotated_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/sc_anno.parquet"
).resolve(strict=True)
organoid_annotated_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/organoid_anno.parquet"
).resolve(strict=True)


# output path
sc_normalized_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/sc_norm.parquet"
).resolve()
organoid_normalized_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/organoid_norm.parquet"
).resolve()

organoid_normalized_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_annotated_profiles = pd.read_parquet(sc_annotated_path)
organoid_annotated_profiles = pd.read_parquet(organoid_annotated_path)

# %%
sc_annotated_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                 255            uM              1
# 1              NF0014_T1                  25            uM              1
# 2              NF0014_T1                  51            uM              1
# 3              NF0014_T1                  63            uM              1
# 4              NF0014_T1                  76            uM              1
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2       Fimepinostat               D5-2            D5
# 3       Fimepinostat               D5-2            D5
# 4       Fimepinostat               D5-2            D5
#
#    Metadata_parent_organoid  Area.Size.Shape_Nuclei_VOLUME  \
# 0                        19                        31267.0
# 1                        -1                        35478.0
# 2                        -1                         9615.0
# 3                        -1                         3784.0
# 4                        -1                         2883.0
#
#    Area.Size.Shape_Nuclei_CENTER.X  ...  \
# 0                      1247.273682  ...
# 1                      1115.733765  ...
# 2                      1050.518799  ...
# 3                       708.924438  ...
# 4                       414.661469  ...
#
#    Intensity_Cytoplasm_Mito_MIN.INTENSITY.EDGE_y  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    Intensity_Cytoplasm_Mito_STD.INTENSITY_y  \
# 0                                      <NA>
# 1                                      <NA>
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
#
#    Intensity_Cytoplasm_Mito_STD.INTENSITY.EDGE_y  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    Intensity_Cytoplasm_Mito_UPPER.QUARTILE.INTENSITY_y  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    Intensity_Cytoplasm_Mito_VOLUME_y          Metadata_Target  Metadata_Class  \
# 0                               <NA>  PI3K and HDAC inhibitor  Small Molecule
# 1                               <NA>  PI3K and HDAC inhibitor  Small Molecule
# 2                               <NA>  PI3K and HDAC inhibitor  Small Molecule
# 3                               <NA>  PI3K and HDAC inhibitor  Small Molecule
# 4                               <NA>  PI3K and HDAC inhibitor  Small Molecule
#
#    Metadata_Therapeutic_Categories  Metadata_patient  Metadata_tumor
# 0                  Investigational            NF0014              T1
# 1                  Investigational            NF0014              T1
# 2                  Investigational            NF0014              T1
# 3                  Investigational            NF0014              T1
# 4                  Investigational            NF0014              T1
#
# [5 rows x 1880 columns]

# %% [markdown]
# ### Normalize the single-cell profiles

# %%
sc_metadata_columns = [x for x in sc_annotated_profiles.columns if "Metadata" in x]

sc_metadata_columns += [
    "Area.Size.Shape_Cell_CENTER.X",
    "Area.Size.Shape_Cell_CENTER.Y",
    "Area.Size.Shape_Cell_CENTER.Z",
]
sc_features_columns = [
    col for col in sc_annotated_profiles.columns if col not in sc_metadata_columns
]

# %%
# find inf values and replace with NaN
sc_annotated_profiles[sc_features_columns] = sc_annotated_profiles[
    sc_features_columns
].replace([float("inf"), -float("inf")], np.nan)

# %%
# normalize the data
sc_normalized_profiles = normalize(
    sc_annotated_profiles,
    features=sc_features_columns,
    meta_features=sc_metadata_columns,
    method="standardize",
    samples="Metadata_treatment == 'DMSO'",
)
sc_normalized_profiles.to_parquet(sc_normalized_output_path, index=False)
sc_normalized_profiles.head()
# Out:
# ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/utils/extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/utils/extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/utils/extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                 255            uM              1
# 1              NF0014_T1                  25            uM              1
# 2              NF0014_T1                  51            uM              1
# 3              NF0014_T1                  63            uM              1
# 4              NF0014_T1                  76            uM              1
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2       Fimepinostat               D5-2            D5
# 3       Fimepinostat               D5-2            D5
# 4       Fimepinostat               D5-2            D5
#
#    Metadata_parent_organoid          Metadata_Target  Metadata_Class  ...  \
# 0                        19  PI3K and HDAC inhibitor  Small Molecule  ...
# 1                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 2                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 3                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
# 4                        -1  PI3K and HDAC inhibitor  Small Molecule  ...
#
#   Intensity_Cytoplasm_Mito_MAX.Z_y Intensity_Cytoplasm_Mito_MEAN.INTENSITY_y  \
# 0                              NaN                                       NaN
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
#
#   Intensity_Cytoplasm_Mito_MEAN.INTENSITY.EDGE_y  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Intensity_Cytoplasm_Mito_MEDIAN.INTENSITY_y  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Intensity_Cytoplasm_Mito_MIN.INTENSITY_y  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Intensity_Cytoplasm_Mito_MIN.INTENSITY.EDGE_y  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Intensity_Cytoplasm_Mito_STD.INTENSITY_y  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Intensity_Cytoplasm_Mito_STD.INTENSITY.EDGE_y  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Intensity_Cytoplasm_Mito_UPPER.QUARTILE.INTENSITY_y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Intensity_Cytoplasm_Mito_VOLUME_y
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
# [5 rows x 1880 columns]

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_annotated_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                  19            uM              1
# 1              NF0014_T1                  15            uM              1
# 2              NF0014_T1                  47            uM              1
# 3              NF0014_T1                  40            uM             10
# 4              NF0014_T1                  37            uM             10
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2          Ketotifen               G6-1            G6
# 3       Mirdametinib               G8-1            G8
# 4       Mirdametinib               C9-2            C9
#
#    Metadata_single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                         1.0                        3268026.0
# 1                        11.0                        5570203.0
# 2                         9.0                        6134128.0
# 3                         8.0                        6416256.0
# 4                        13.0                       14239851.0
#
#    Area.Size.Shape_Organoid_CENTER.X  ...  \
# 0                         938.570068  ...
# 1                         950.582825  ...
# 2                         795.807983  ...
# 3                         769.689636  ...
# 4                         817.411133  ...
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.888459
# 1                                           0.853993
# 2                                           0.875041
# 3                                           0.943387
# 4                                           0.818021
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                 8.625683
# 1                                 7.177906
# 2                                13.244656
# 3                                 5.153550
# 4                                12.778783
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                 1.346913
# 1                                 1.556027
# 2                                 1.343332
# 3                                 0.835848
# 4                                 2.293907
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                702.361139
# 1                                297.955168
# 2                               1153.970316
# 3                                479.284825
# 4                                971.364210
#
#    Texture_Organoid_Mito_Variance_256.3                   Metadata_Target  \
# 0                            188.512030           PI3K and HDAC inhibitor
# 1                             85.399048           PI3K and HDAC inhibitor
# 2                            303.579081  histamine H1 receptor antagonist
# 3                            121.910734                  MEK1/2 inhibitor
# 4                            258.637076                  MEK1/2 inhibitor
#
#    Metadata_Class  Metadata_Therapeutic_Categories  Metadata_patient  \
# 0  Small Molecule                  Investigational            NF0014
# 1  Small Molecule                  Investigational            NF0014
# 2  Small Molecule             Anti-Allergic Agents            NF0014
# 3  Small Molecule                 Kinase Inhibitor            NF0014
# 4  Small Molecule                 Kinase Inhibitor            NF0014
#
#    Metadata_tumor
# 0              T1
# 1              T1
# 2              T1
# 3              T1
# 4              T1
#
# [5 rows x 464 columns]

# %%
organoid_metadata_columns = [
    x for x in organoid_annotated_profiles.columns if "Metadata" in x
]
organoid_metadata_columns += [
    "Area.Size.Shape_Organoid_CENTER.X",
    "Area.Size.Shape_Organoid_CENTER.Y",
    "Area.Size.Shape_Organoid_CENTER.Z",
]
organoid_features_columns = [
    col
    for col in organoid_annotated_profiles.columns
    if col not in organoid_metadata_columns
]
# normalize the data
organoid_normalized_profiles = normalize(
    organoid_annotated_profiles,
    features=organoid_features_columns,
    meta_features=organoid_metadata_columns,
    method="standardize",
    samples="Metadata_treatment == 'DMSO'",
)
organoid_normalized_profiles.to_parquet(organoid_normalized_output_path, index=False)
organoid_normalized_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                  19            uM              1
# 1              NF0014_T1                  15            uM              1
# 2              NF0014_T1                  47            uM              1
# 3              NF0014_T1                  40            uM             10
# 4              NF0014_T1                  37            uM             10
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2          Ketotifen               G6-1            G6
# 3       Mirdametinib               G8-1            G8
# 4       Mirdametinib               C9-2            C9
#
#    Metadata_single_cell_count                   Metadata_Target  \
# 0                         1.0           PI3K and HDAC inhibitor
# 1                        11.0           PI3K and HDAC inhibitor
# 2                         9.0  histamine H1 receptor antagonist
# 3                         8.0                  MEK1/2 inhibitor
# 4                        13.0                  MEK1/2 inhibitor
#
#    Metadata_Class  ... Texture_Organoid_Mito_Difference.Entropy_256.3  \
# 0  Small Molecule  ...                                      -0.744079
# 1  Small Molecule  ...                                      -0.018758
# 2  Small Molecule  ...                                      -0.825789
# 3  Small Molecule  ...                                      -1.928917
# 4  Small Molecule  ...                                       1.306989
#
#   Texture_Organoid_Mito_Difference.Variance_256.3  \
# 0                                        0.929269
# 1                                        0.263903
# 2                                        0.752942
# 3                                        1.998597
# 4                                       -0.622370
#
#   Texture_Organoid_Mito_Entropy_256.3  \
# 0                           -0.876963
# 1                           -0.497285
# 2                           -0.748346
# 3                           -1.865807
# 4                            1.532605
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -0.149888
# 1                                           1.297494
# 2                                           0.050014
# 3                                          -0.723970
# 4                                           0.813374
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.453953
# 1                                          -1.614111
# 2                                          -0.465444
# 3                                          -1.483790
# 4                                           0.531467
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.924721
# 1                                           0.248123
# 2                                           0.661318
# 3                                           2.002970
# 4                                          -0.458024
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -1.012954
# 1                                -1.166291
# 2                                -0.523751
# 3                                -1.380694
# 4                                -0.573092
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                -0.840821
# 1                                -0.386110
# 2                                -0.848608
# 3                                -1.952115
# 4                                 1.218386
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                 -0.826647
# 1                                 -1.094204
# 2                                 -0.527859
# 3                                 -0.974235
# 4                                 -0.648673
#
#    Texture_Organoid_Mito_Variance_256.3
# 0                             -0.812516
# 1                             -1.082140
# 2                             -0.511635
# 3                             -0.986668
# 4                             -0.629151
#
# [5 rows x 464 columns]
