# %%
import itertools
import pathlib
import sys
from itertools import product

import numpy as np
import pandas as pd

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

sys.path.append(f"{root_dir}/3.cellprofiling/featurization_utils/")
from loading_classes import ImageSetLoader

# %%
patient_id_file = pathlib.Path(f"{root_dir}/data/patient_IDs.txt").resolve(strict=True)
patients = pd.read_csv(
    patient_id_file, header=None, names=["patient_id"]
).patient_id.tolist()

input_combinations_path = pathlib.Path(
    f"{root_dir}/3.cellprofiling/load_data/input_combinations.txt"
)
input_combinations_path.parent.mkdir(parents=True, exist_ok=True)

# %%
features = [
    "AreaSizeShape",
    "Colocalization",
    "Granularity",
    "Intensity",
    "Neighbors",
    "Texture",
]

# %%
channel_mapping = {
    "DNA": "405",
    "AGP": "488",
    "ER": "555",
    "Mito": "640",
    "BF": "TRANS",
    "Nuclei": "nuclei_",
    "Cell": "cell_",
    "Cytoplasm": "cytoplasm_",
    "Organoid": "organoid_",
}

# %%
# example image set path to get the image set loader working
image_set_path = pathlib.Path(f"{root_dir}/data/NF0014/profiling_input_images/C2-1/")
image_set_loader = ImageSetLoader(
    image_set_path=image_set_path,
    anisotropy_spacing=(1, 0.1, 0.1),
    channel_mapping=channel_mapping,
)

# %%
output_dict = {
    "patient": [],
    "well_fov": [],
    "feature": [],
    "compartment": [],
    "channel": [],
    "processor_type": [],
}
processor_types = [
    "CPU",
    # "GPU"
]

# %%
# get all channel combinations
channel_combinations = list(itertools.combinations(image_set_loader.image_names, 2))

# %%
for patient in patients:
    # get the well_fov for each patient
    patient_well_fovs = pathlib.Path(
        f"{root_dir}/data/{patient}/profiling_input_images/"
    ).glob("*")
    for well_fov in patient_well_fovs:
        print(f"Processing patient: {patient}, well_fov: {well_fov}")
        well_fov = well_fov.name
        for feature in features:
            if feature == "Neighbors":
                output_dict["patient"].append(patient)
                output_dict["well_fov"].append(well_fov)
                output_dict["feature"].append("Neighbors")
                output_dict["compartment"].append("Nuclei")
                output_dict["channel"].append("DNA")
                output_dict["processor_type"].append("CPU")
            for compartment in image_set_loader.compartments:
                if feature == "AreaSizeShape":
                    for processor_type in processor_types:
                        output_dict["patient"].append(patient)
                        output_dict["well_fov"].append(well_fov)
                        output_dict["feature"].append("AreaSizeShape")
                        output_dict["compartment"].append(compartment)
                        output_dict["channel"].append("DNA")
                        output_dict["processor_type"].append(processor_type)
                elif feature == "Colocalization":
                    for channel in channel_combinations:
                        for processor_type in processor_types:
                            output_dict["patient"].append(patient)
                            output_dict["well_fov"].append(well_fov)
                            output_dict["feature"].append("Colocalization")
                            output_dict["compartment"].append(compartment)
                            output_dict["channel"].append(channel[0] + "." + channel[1])
                            output_dict["processor_type"].append(processor_type)
                for channel in image_set_loader.image_names:
                    if (
                        feature != "Neighbors"
                        and feature != "AreaSizeShape"
                        and feature != "Colocalization"
                    ):
                        if feature == "Granularity":
                            output_dict["patient"].append(patient)
                            output_dict["well_fov"].append(well_fov)
                            output_dict["feature"].append(feature)
                            output_dict["compartment"].append(compartment)
                            output_dict["channel"].append(channel)
                            output_dict["processor_type"].append("CPU")
                        elif feature == "Intensity":
                            for processor_type in processor_types:
                                output_dict["patient"].append(patient)
                                output_dict["well_fov"].append(well_fov)
                                output_dict["feature"].append(feature)
                                output_dict["compartment"].append(compartment)
                                output_dict["channel"].append(channel)
                                output_dict["processor_type"].append(processor_type)
                        elif feature == "Texture":
                            output_dict["patient"].append(patient)
                            output_dict["well_fov"].append(well_fov)
                            output_dict["feature"].append(feature)
                            output_dict["compartment"].append(compartment)
                            output_dict["channel"].append(channel)
                            output_dict["processor_type"].append("CPU")
                        else:
                            raise ValueError(f"Unknown feature: {feature}")
# Out:
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G8-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D5-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F8-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G11-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G7-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E3-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C11-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E11-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D11-3
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E7-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C3-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D4-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E3-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D8-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G2-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E11-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G5-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C5-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D3-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C5-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D6-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G4-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E10-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C4-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F6-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F4-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F4-3
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F3-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F4-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D8-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G10-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F8-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G4-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C8-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E8-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G10-3
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F11-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F7-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F5-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G5-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D2-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C8-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E5-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G6-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C7-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E7-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C6-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D4-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C7-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D11-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E10-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G7-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G10-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D10-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C6-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F11-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C10-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C2-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F6-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F2-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F9-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G9-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C9-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F9-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E6-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D7-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C4-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D3-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D9-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F10-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G11-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E9-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E2-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G3-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D2-3
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E2-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E8-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C11-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F2-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D9-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D9-3
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C9-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D5-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C3-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G6-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D11-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C2-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D7-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E5-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G2-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E6-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D2-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G9-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D6-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E4-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G8-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/G3-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/D10-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F7-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/E4-2
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F10-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/F5-1
# Processing patient: NF0014, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0014/profiling_input_images/C10-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G8-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/D5-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F8-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G7-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E3-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E11-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E7-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F3-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C3-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/D4-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E3-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E5-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E11-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G5-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E9-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F8-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C5-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G8-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E4-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C5-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/D9-4
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/D6-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E10-4
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G6-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G4-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E10-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C4-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F6-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G5-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E9-4
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F11-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F4-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C4-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F4-3
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F3-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F4-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G10-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/F8-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/G4-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/C8-1
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images/E8-2
# Processing patient: NF0016, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/NF0016/profiling_input_images
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G10-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G10-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C3-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G5-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E9-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D2-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C6-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D7-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F2-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G8-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F2-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F7-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G6-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C7-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E7-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D11-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C2-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D7-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E5-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G2-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E6-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D2-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D4-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F10-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G9-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D3-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G9-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D6-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E9-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C3-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E5-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E4-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G8-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C10-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C9-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C7-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G3-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G8-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E5-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C2-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F5-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E9-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D10-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E6-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F3-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E4-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E2-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C4-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D5-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F5-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F8-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F6-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D9-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F2-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F11-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C9-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F7-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D10-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C6-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F2-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F8-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E4-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F7-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E4-2
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F10-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C8-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G2-4
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/F5-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C11-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E8-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D6-7
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C10-3
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/C10-1
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/G8-5
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/E5-6
# Processing patient: SARCO361, well_fov: /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/data/SARCO361/profiling_input_images/D10-3

# %%
df = pd.DataFrame(output_dict)
print(f"Total combinations: {df.shape[0]}")
df.head()
# Out:
# Total combinations: 198870
#   patient well_fov         feature compartment  channel processor_type
# 0  NF0014     G8-1   AreaSizeShape        Cell      DNA            CPU
# 1  NF0014     G8-1   AreaSizeShape   Cytoplasm      DNA            CPU
# 2  NF0014     G8-1   AreaSizeShape      Nuclei      DNA            CPU
# 3  NF0014     G8-1   AreaSizeShape    Organoid      DNA            CPU
# 4  NF0014     G8-1  Colocalization        Cell  DNA.AGP            CPU

# %%
# number of combinations we should have
# per well_fov
area_combos = len(image_set_loader.compartments) * len(processor_types)
coloc_combos = (
    len(channel_combinations)
    * len(image_set_loader.compartments)
    * len(processor_types)
)
intensity_combos = (
    len(image_set_loader.image_names)
    * len(image_set_loader.compartments)
    * len(processor_types)
)
granularity_combos = len(image_set_loader.image_names) * len(
    image_set_loader.compartments
)
neighbors_combos = 1  # Neighbors is always DNA and Nuclei
texture_combos = len(image_set_loader.image_names) * len(image_set_loader.compartments)
total_well_fov_combos = (
    area_combos
    + coloc_combos
    + intensity_combos
    + granularity_combos
    + neighbors_combos
    + texture_combos
)
total_patient_well_fov_combos = len(np.unique(df["patient"] + "_" + df["well_fov"]))
total_combos = total_well_fov_combos * total_patient_well_fov_combos
# print the total number of combinations
print(
    f"For {total_patient_well_fov_combos} patient-well_fov combinations, we have {total_combos} total combinations across all features."
)
# Out:
# For 1894 patient-well_fov combinations, we have 198870 total combinations across all features.

# %%
# write to a txt file with each row as a combination
# each column is a feature of the combination
df.to_csv(input_combinations_path, sep="\t", index=False)
