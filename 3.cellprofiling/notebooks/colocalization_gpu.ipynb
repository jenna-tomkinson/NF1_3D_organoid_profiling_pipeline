# %%
import argparse
import os
import pathlib
import sys
import time

import psutil

sys.path.append("../featurization_utils")
import itertools
from typing import Dict

import cucim.skimage.measure
import cupy
import cupyx
import cupyx.scipy.ndimage
import numpy as np
import pandas as pd
import scipy
import skimage
from colocalization_utils_gpu import (
    measure_3D_colocalization_gpu,
    prepare_two_images_for_colocalization_gpu,
)
from loading_classes import ImageSetLoader, ObjectLoader, TwoObjectLoader
from resource_profiling_util import get_mem_and_time_profiling

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
if in_notebook:
    from tqdm.notebook import tqdm
else:
    from tqdm import tqdm

import warnings

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--well_fov",
        type=str,
        default="None",
        help="Well and field of view to process, e.g. 'A01_1'",
    )

    args = argparser.parse_args()
    well_fov = args.well_fov
    if well_fov == "None":
        raise ValueError(
            "Please provide a well and field of view to process, e.g. 'A01_1'"
        )

    image_set_path = pathlib.Path(f"../../data/NF0014/cellprofiler/{well_fov}/")
else:
    well_fov = "C4-2"
    image_set_path = pathlib.Path(f"../../data/NF0014/cellprofiler/{well_fov}/")

# %%
channel_mapping = {
    "DNA": "405",
    "AGP": "488",
    "ER": "555",
    "Mito": "640",
    "BF": "TRANS",
    "Nuclei": "nuclei_",
    "Cell": "cell_",
    "Cytoplasm": "cytoplasm_",
    "Organoid": "organoid_",
}

# %%
image_set_loader = ImageSetLoader(
    image_set_path=image_set_path,
    anisotropy_spacing=(1, 0.1, 0.1),
    channel_mapping=channel_mapping,
)

# %%
# get all channel combinations
channel_combinations = list(itertools.combinations(image_set_loader.image_names, 2))

# %%
start_time = time.time()
# get starting memory (cpu)
start_mem = psutil.Process(os.getpid()).memory_info().rss / 1024**2

# %%
for compartment in tqdm(
    image_set_loader.compartments, desc="Processing compartments", position=0
):
    for channel1, channel2 in tqdm(
        channel_combinations,
        desc="Processing channel combinations",
        leave=False,
        position=1,
    ):
        output_dir = pathlib.Path(
            f"../results/{image_set_loader.image_set_name}/Colocalization_{compartment}_{channel1}.{channel2}_features"
        )
        output_dir.mkdir(parents=True, exist_ok=True)
        coloc_loader = TwoObjectLoader(
            image_set_loader=image_set_loader,
            compartment=compartment,
            channel1=channel1,
            channel2=channel2,
        )
        list_of_dfs = []
        for object_id in tqdm(
            coloc_loader.object_ids,
            desc="Processing object IDs",
            leave=False,
            position=2,
        ):
            cropped_image1, cropped_image2 = prepare_two_images_for_colocalization_gpu(
                label_object1=coloc_loader.label_image,
                label_object2=coloc_loader.label_image,
                image_object1=coloc_loader.image1,
                image_object2=coloc_loader.image2,
                object_id1=object_id,
                object_id2=object_id,
            )
            colocalization_features = measure_3D_colocalization_gpu(
                cropped_image_1=cropped_image1,
                cropped_image_2=cropped_image2,
                thr=15,
                fast_costes="Accurate",
            )
            coloc_df = pd.DataFrame(colocalization_features, index=[0])
            coloc_df.columns = [
                f"Colocalization_{compartment}_{channel1}.{channel2}_{col}"
                for col in coloc_df.columns
            ]
            coloc_df.insert(0, "object_id", object_id)
            coloc_df.insert(1, "image_set", image_set_loader.image_set_name)
            coloc_df.to_parquet(output_dir / f"object_{object_id}.parquet")
# Out:
# Processing object IDs:   0%|          | 0/45 [00:00<?, ?it/s]
#    object_id image_set  Colocalization_Nuclei_DNA.AGP_MEAN.CORRELATION.COEFF  \
# 0          2      C4-2                                     -218328.568829
# 1          3      C4-2                                       -1025.087762
# 2          5      C4-2                                       -3215.644929
# 3          8      C4-2                                         961.222803
# 4         13      C4-2                                      -15556.348911
#
#    Colocalization_Nuclei_DNA.AGP_MEDIAN.CORRELATION.COEFF  \
# 0                                     -218328.568829
# 1                                       -1025.087762
# 2                                       -3215.644929
# 3                                         961.222803
# 4                                      -15556.348911
#
#    Colocalization_Nuclei_DNA.AGP_MIN.CORRELATION.COEFF  \
# 0                                     -218328.568829
# 1                                       -1025.087762
# 2                                       -3215.644929
# 3                                         961.222803
# 4                                      -15556.348911
#
#    Colocalization_Nuclei_DNA.AGP_MAX.CORRELATION.COEFF  \
# 0                                     -218328.568829
# 1                                       -1025.087762
# 2                                       -3215.644929
# 3                                         961.222803
# 4                                      -15556.348911
#
#    Colocalization_Nuclei_DNA.AGP_MEAN.MANDERS.COEFF.M1  \
# 0                                           0.291578
# 1                                           0.654384
# 2                                           1.000000
# 3                                           1.000000
# 4                                           0.482011
#
#    Colocalization_Nuclei_DNA.AGP_MEDIAN.MANDERS.COEFF.M1  \
# 0                                           0.291578
# 1                                           0.654384
# 2                                           1.000000
# 3                                           1.000000
# 4                                           0.482011
#
#    Colocalization_Nuclei_DNA.AGP_MIN.MANDERS.COEFF.M1  \
# 0                                           0.291578
# 1                                           0.654384
# 2                                           1.000000
# 3                                           1.000000
# 4                                           0.482011
#
#    Colocalization_Nuclei_DNA.AGP_MAX.MANDERS.COEFF.M1  ...  \
# 0                                           0.291578   ...
# 1                                           0.654384   ...
# 2                                           1.000000   ...
# 3                                           1.000000   ...
# 4                                           0.482011   ...
#
#    Colocalization_Nuclei_DNA.AGP_MIN.K2  Colocalization_Nuclei_DNA.AGP_MAX.K2  \
# 0                              0.979210                              0.979210
# 1                              1.249190                              1.249190
# 2                              0.880917                              0.880917
# 3                             10.947845                             10.947845
# 4                              0.964438                              0.964438
#
#    Colocalization_Nuclei_DNA.AGP_MEAN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.214350
# 1                                           0.006829
# 2                                           0.209657
# 3                                           1.000000
# 4                                           0.194177
#
#    Colocalization_Nuclei_DNA.AGP_MEDIAN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.214350
# 1                                           0.006829
# 2                                           0.209657
# 3                                           1.000000
# 4                                           0.194177
#
#    Colocalization_Nuclei_DNA.AGP_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.214350
# 1                                           0.006829
# 2                                           0.209657
# 3                                           1.000000
# 4                                           0.194177
#
#    Colocalization_Nuclei_DNA.AGP_MAX.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.214350
# 1                                           0.006829
# 2                                           0.209657
# 3                                           1.000000
# 4                                           0.194177
#
#    Colocalization_Nuclei_DNA.AGP_MEAN.MANDERS.COEFF.COSTES.M2  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Colocalization_Nuclei_DNA.AGP_MEDIAN.MANDERS.COEFF.COSTES.M2  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Colocalization_Nuclei_DNA.AGP_MIN.MANDERS.COEFF.COSTES.M2  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    Colocalization_Nuclei_DNA.AGP_MAX.MANDERS.COEFF.COSTES.M2
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
# [5 rows x 34 columns]

# %%
end_mem = psutil.Process(os.getpid()).memory_info().rss / 1024**2
end_time = time.time()
get_mem_and_time_profiling(
    start_mem=start_mem,
    end_mem=end_mem,
    start_time=start_time,
    end_time=end_time,
    process_name="Colocalization",
    well_fov=well_fov,
    CPU_GPU="GPU",
)
# Out:
# Elapsed time: 28.57 seconds
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
