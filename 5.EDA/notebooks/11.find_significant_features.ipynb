# %%
import pathlib
import warnings

import pandas as pd
import statsmodels.formula.api as smf

warnings.filterwarnings("ignore")  # Ignore all warnings
warnings.simplefilter("ignore")  # Additional suppression method

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
if in_notebook:
    from tqdm.notebook import tqdm
else:
    from tqdm import tqdm
# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

# %%
profile_dict = {
    "organoid_fs": {
        "input_profile_path": pathlib.Path(
            root_dir, "5.EDA/results/linear_modeling/organoid_fs.parquet"
        ),
        "metadata_columns": [
            "patient",
            "object_id",
            "unit",
            "dose",
            "treatment",
            "Target",
            "Class",
            "image_set",
            "Well",
            "Therapeutic_Categories",
            "single_cell_count",
        ],
    },
    "single_cell_fs": {
        "input_profile_path": pathlib.Path(
            root_dir, "5.EDA/results/linear_modeling/sc_fs.parquet"
        ),
        "metadata_columns": [
            "patient",
            "object_id",
            "unit",
            "dose",
            "treatment",
            "Target",
            "Class",
            "image_set",
            "Well",
            "Therapeutic_Categories",
            "parent_organoid",
        ],
    },
}

# %% [markdown]
# ## Filter significant features
# pvalue threshold is set to 0.05 - statistically significant features
# rsquared threshold is set to 0.5 - the explained variance is at least 50% of the total variance
# rsquared adjusted threshold is set to positive values - the model performs better than the mean

# %% [markdown]
# ### Single Cell

# %%
df = pd.read_parquet(
    profile_dict["single_cell_fs"]["input_profile_path"],
)
print(df.shape)
# Out:
# (165584, 15)

# %%
pvalue_threshold_max = 0.05  # significance threshold for p-values
rsquared_threshold_min = 0.5  # 50% of variance explained by the model
rsquared_adj_threshold_min = 0  # the model performs better than the null model
coefficient_threshold_min = 1  # minimum effect size of 1

# %%
# filter significant features
df_filtered = df[
    (df["pvalue"] < pvalue_threshold_max)
    & (df["rsquared"] > rsquared_threshold_min)
    & (df["rsquared_adj"] > rsquared_adj_threshold_min)
    & (df["coefficient"].abs() > coefficient_threshold_min)
].copy()
print(df_filtered.shape)
df_filtered.head()
# Out:
# (35, 15)
#       patient   treatment                               feature  rsquared  \
# 51127  NF0018  Copanlisib    Colocalization_Cell_DNAMito_MEANK2  0.504153
# 51128  NF0018  Copanlisib  Colocalization_Cell_DNAMito_MEDIANK2  0.504153
# 51129  NF0018  Copanlisib     Colocalization_Cell_DNAMito_MINK2  0.504153
# 51130  NF0018  Copanlisib     Colocalization_Cell_DNAMito_MAXK2  0.504153
# 51174  NF0018  Copanlisib               Intensity_Cell_AGP_CMIX  0.569113
#
#        rsquared_adj      fvalue        pvalue  coefficient     intercept  \
# 51127      0.500710  146.412102  1.078662e-23    59.369253 -1.052110e-15
# 51128      0.500710  146.412102  1.078662e-23    59.369253 -1.052110e-15
# 51129      0.500710  146.412102  1.078662e-23    59.369253 -1.052110e-15
# 51130      0.500710  146.412102  1.078662e-23    59.369253 -1.052110e-15
# 51174      0.566121  190.194580  4.133556e-28    80.036130  2.706169e-16
#
#          Feature_type Compartment  Channel Measurement Extra_info  pvalue_fdr
# 51127  Colocalization        Cell  DNAMito      MEANK2       None         NaN
# 51128  Colocalization        Cell  DNAMito    MEDIANK2       None         NaN
# 51129  Colocalization        Cell  DNAMito       MINK2       None         NaN
# 51130  Colocalization        Cell  DNAMito       MAXK2       None         NaN
# 51174       Intensity        Cell      AGP        CMIX       None         NaN

# %%
df_filtered["treatment"].unique()
# Out:
# array(['Copanlisib', 'Selumetinib'], dtype=object)

# %%
df_filtered["patient"].unique()
# Out:
# array(['NF0018', 'NF0030'], dtype=object)

# %%
df_filtered["feature"].unique()
# Out:
# array(['Colocalization_Cell_DNAMito_MEANK2',
#        'Colocalization_Cell_DNAMito_MEDIANK2',
#        'Colocalization_Cell_DNAMito_MINK2',
#        'Colocalization_Cell_DNAMito_MAXK2', 'Intensity_Cell_AGP_CMIX',
#        'Intensity_Cell_AGP_CMIY', 'Intensity_Cell_AGP_CMIZ',
#        'Granularity_Cell_AGP_GRANULARITY1',
#        'Granularity_Cell_AGP_GRANULARITY2',
#        'Colocalization_Cytoplasm_DNAMito_MEANK2',
#        'Colocalization_Cytoplasm_DNAMito_MEDIANK2',
#        'Colocalization_Cytoplasm_DNAMito_MINK2',
#        'Colocalization_Cytoplasm_DNAMito_MAXK2',
#        'Intensity_Cytoplasm_AGP_CMIX',
#        'Granularity_Cytoplasm_AGP_GRANULARITY1',
#        'Colocalization_Nuclei_DNAMito_MEANK2',
#        'Colocalization_Nuclei_DNAMito_MEDIANK2',
#        'Colocalization_Nuclei_DNAMito_MINK2',
#        'Colocalization_Nuclei_DNAMito_MAXK2',
#        'Colocalization_Cell_AGPMito_MEANK2',
#        'Colocalization_Cell_AGPMito_MEDIANK2',
#        'Colocalization_Cell_AGPMito_MINK2',
#        'Colocalization_Cell_AGPMito_MAXK2',
#        'Colocalization_Cytoplasm_AGPMito_MEANK2',
#        'Colocalization_Cytoplasm_AGPMito_MEDIANK2',
#        'Colocalization_Cytoplasm_AGPMito_MINK2',
#        'Colocalization_Cytoplasm_AGPMito_MAXK2'], dtype=object)

# %% [markdown]
# ### Organoid

# %%
df = pd.read_parquet(
    profile_dict["organoid_fs"]["input_profile_path"],
)
print(df.shape)
# Out:
# (57024, 15)

# %%
pvalue_threshold_max = 0.05
rsquared_threshold_min = 0.4
rsquared_adj_threshold_min = 0
coefficient_threshold_min = 1

# %%
# filter significant features
df_filtered = df[
    (df["pvalue"] < pvalue_threshold_max)
    & (df["rsquared"] > rsquared_threshold_min)
    & (df["rsquared_adj"] > rsquared_adj_threshold_min)
    & (df["coefficient"].abs() > coefficient_threshold_min)
].copy()
print(df_filtered.shape)
df_filtered.head()
# Out:
# (390, 15)
#     patient     treatment                                    feature  \
# 283  NF0014  Mirdametinib         Intensity_Organoid_ER_STDINTENSITY
# 284  NF0014  Mirdametinib     Intensity_Organoid_ER_STDINTENSITYEDGE
# 434  NF0014  Fimepinostat             AreaSizeShape_Organoid_CENTERZ
# 435  NF0014  Fimepinostat              AreaSizeShape_Organoid_VOLUME
# 438  NF0014  Fimepinostat  AreaSizeShape_Organoid_EQUIVALENTDIAMETER
#
#      rsquared  rsquared_adj     fvalue    pvalue  coefficient     intercept  \
# 283  0.447425      0.423400  18.623301  0.000256    -1.745595  1.536424e-16
# 284  0.402125      0.376130  15.469554  0.000664    -1.665961  2.317867e-17
# 434  0.427737      0.397618  14.201498  0.001300   -16.857658  2.280302e+01
# 435  0.456506      0.427901  15.958957  0.000775    -2.108811  5.228555e-16
# 438  0.628190      0.608621  32.101402  0.000018    -3.092539  6.538228e-17
#
#       Feature_type Compartment Channel         Measurement Extra_info  \
# 283      Intensity    Organoid      ER        STDINTENSITY       None
# 284      Intensity    Organoid      ER    STDINTENSITYEDGE       None
# 434  AreaSizeShape    Organoid    None             CENTERZ       None
# 435  AreaSizeShape    Organoid    None              VOLUME       None
# 438  AreaSizeShape    Organoid    None  EQUIVALENTDIAMETER       None
#
#      pvalue_fdr
# 283         NaN
# 284         NaN
# 434         NaN
# 435         NaN
# 438         NaN

# %%
df_filtered["treatment"].unique()
# Out:
# array(['Mirdametinib', 'Fimepinostat', 'Staurosporine', 'Binimetinib',
#        'Copanlisib', 'Cabozantinib', 'Onalespib', 'Rapamycin', 'Digoxin',
#        'Ketotifen', 'Trametinib', 'Linsitinib', 'Imatinib', 'Everolimus',
#        'Selumetinib'], dtype=object)

# %%
df_filtered["patient"].unique()
# Out:
# array(['NF0014', 'NF0016', 'NF0018', 'NF0021', 'NF0030', 'SARCO219'],
#       dtype=object)

# %%
df_filtered["feature"].unique()
# Out:
# array(['Intensity_Organoid_ER_STDINTENSITY',
#        'Intensity_Organoid_ER_STDINTENSITYEDGE',
#        'AreaSizeShape_Organoid_CENTERZ', 'AreaSizeShape_Organoid_VOLUME',
#        'AreaSizeShape_Organoid_EQUIVALENTDIAMETER',
#        'Colocalization_Organoid_AGPER_MEANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_AGPER_MEDIANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_AGPER_MINMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_AGPER_MAXMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAAGP_MEANCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAAGP_MEDIANCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAAGP_MINCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAAGP_MAXCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAAGP_MEANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAAGP_MEDIANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAAGP_MINMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAAGP_MAXMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAER_MEANCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAER_MEDIANCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAER_MINCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAER_MAXCORRELATIONCOEFF',
#        'Colocalization_Organoid_DNAER_MEANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAER_MEDIANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAER_MINMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAER_MAXMANDERSCOEFFCOSTESM1',
#        'Intensity_Organoid_AGP_CMZ', 'Intensity_Organoid_AGP_DIFFZ',
#        'Intensity_Organoid_AGP_EDGECOUNT',
#        'Intensity_Organoid_AGP_VOLUME', 'Intensity_Organoid_DNA_CMZ',
#        'Intensity_Organoid_DNA_CMIX', 'Intensity_Organoid_DNA_DIFFZ',
#        'Intensity_Organoid_DNA_EDGECOUNT',
#        'Intensity_Organoid_DNA_INTEGRATEDINTENSITYEDGE',
#        'Intensity_Organoid_DNA_LOWERQUARTILEINTENSITY',
#        'Intensity_Organoid_DNA_MEANINTENSITYEDGE',
#        'Intensity_Organoid_DNA_MEDIANINTENSITY',
#        'Intensity_Organoid_DNA_UPPERQUARTILEINTENSITY',
#        'Intensity_Organoid_DNA_VOLUME', 'Intensity_Organoid_ER_CMZ',
#        'Intensity_Organoid_ER_CMIX', 'Intensity_Organoid_ER_DIFFZ',
#        'Intensity_Organoid_ER_EDGECOUNT',
#        'Intensity_Organoid_ER_INTEGRATEDINTENSITY',
#        'Intensity_Organoid_ER_INTEGRATEDINTENSITYEDGE',
#        'Intensity_Organoid_ER_LOWERQUARTILEINTENSITY',
#        'Intensity_Organoid_ER_MADINTENSITY',
#        'Intensity_Organoid_ER_MEANINTENSITY',
#        'Intensity_Organoid_ER_MEANINTENSITYEDGE',
#        'Intensity_Organoid_ER_MEDIANINTENSITY',
#        'Intensity_Organoid_ER_UPPERQUARTILEINTENSITY',
#        'Intensity_Organoid_ER_VOLUME', 'Intensity_Organoid_Mito_CMZ',
#        'Intensity_Organoid_Mito_DIFFZ',
#        'Intensity_Organoid_Mito_EDGECOUNT',
#        'Intensity_Organoid_Mito_INTEGRATEDINTENSITYEDGE',
#        'Intensity_Organoid_Mito_VOLUME',
#        'Granularity_Organoid_AGP_GRANULARITY10',
#        'Granularity_Organoid_AGP_GRANULARITY5',
#        'Granularity_Organoid_AGP_GRANULARITY6',
#        'Granularity_Organoid_AGP_GRANULARITY7',
#        'Granularity_Organoid_AGP_GRANULARITY8',
#        'Granularity_Organoid_AGP_GRANULARITY9',
#        'Granularity_Organoid_DNA_GRANULARITY10',
#        'Granularity_Organoid_DNA_GRANULARITY11',
#        'Granularity_Organoid_DNA_GRANULARITY12',
#        'Granularity_Organoid_DNA_GRANULARITY13',
#        'Granularity_Organoid_DNA_GRANULARITY14',
#        'Granularity_Organoid_DNA_GRANULARITY15',
#        'Granularity_Organoid_DNA_GRANULARITY5',
#        'Granularity_Organoid_DNA_GRANULARITY6',
#        'Granularity_Organoid_DNA_GRANULARITY7',
#        'Granularity_Organoid_DNA_GRANULARITY8',
#        'Granularity_Organoid_DNA_GRANULARITY9',
#        'Granularity_Organoid_ER_GRANULARITY10',
#        'Granularity_Organoid_ER_GRANULARITY5',
#        'Granularity_Organoid_ER_GRANULARITY6',
#        'Granularity_Organoid_ER_GRANULARITY7',
#        'Granularity_Organoid_ER_GRANULARITY8',
#        'Granularity_Organoid_ER_GRANULARITY9',
#        'Granularity_Organoid_Mito_GRANULARITY10',
#        'Granularity_Organoid_Mito_GRANULARITY5',
#        'Granularity_Organoid_Mito_GRANULARITY6',
#        'Granularity_Organoid_Mito_GRANULARITY7',
#        'Granularity_Organoid_Mito_GRANULARITY8',
#        'Granularity_Organoid_Mito_GRANULARITY9',
#        'Texture_Organoid_AGP_InformationMeasureofCorrelation2_2563',
#        'Texture_Organoid_DNA_Correlation_2563',
#        'Texture_Organoid_DNA_InformationMeasureofCorrelation2_2563',
#        'Texture_Organoid_ER_Correlation_2563',
#        'Texture_Organoid_ER_InformationMeasureofCorrelation2_2563',
#        'Intensity_Organoid_AGP_IX', 'Intensity_Organoid_AGP_IY',
#        'Intensity_Organoid_DNA_IX', 'Intensity_Organoid_DNA_IY',
#        'Intensity_Organoid_DNA_INTEGRATEDINTENSITY',
#        'Intensity_Organoid_DNA_STDINTENSITY', 'Intensity_Organoid_ER_IX',
#        'Intensity_Organoid_ER_IY', 'Intensity_Organoid_ER_MININTENSITY',
#        'Intensity_Organoid_Mito_IX', 'Intensity_Organoid_Mito_IY',
#        'Intensity_Organoid_Mito_INTEGRATEDINTENSITY',
#        'Granularity_Organoid_AGP_GRANULARITY1',
#        'Granularity_Organoid_AGP_GRANULARITY2',
#        'Granularity_Organoid_AGP_GRANULARITY3',
#        'Granularity_Organoid_DNA_GRANULARITY1',
#        'Granularity_Organoid_DNA_GRANULARITY2',
#        'Granularity_Organoid_ER_GRANULARITY1',
#        'Granularity_Organoid_ER_GRANULARITY2',
#        'Granularity_Organoid_ER_GRANULARITY3',
#        'Granularity_Organoid_Mito_GRANULARITY1',
#        'Granularity_Organoid_Mito_GRANULARITY2',
#        'Granularity_Organoid_Mito_GRANULARITY3',
#        'Texture_Organoid_AGP_AngularSecondMoment_2563',
#        'Texture_Organoid_DNA_AngularSecondMoment_2563',
#        'Texture_Organoid_DNA_DifferenceEntropy_2563',
#        'Texture_Organoid_DNA_DifferenceVariance_2563',
#        'Texture_Organoid_DNA_Entropy_2563',
#        'Texture_Organoid_DNA_InverseDifferenceMoment_2563',
#        'Texture_Organoid_DNA_SumAverage_2563',
#        'Texture_Organoid_DNA_SumEntropy_2563',
#        'Texture_Organoid_ER_AngularSecondMoment_2563',
#        'Texture_Organoid_ER_DifferenceEntropy_2563',
#        'Texture_Organoid_ER_DifferenceVariance_2563',
#        'Texture_Organoid_ER_Entropy_2563',
#        'Texture_Organoid_ER_InverseDifferenceMoment_2563',
#        'Texture_Organoid_ER_SumEntropy_2563',
#        'Texture_Organoid_Mito_AngularSecondMoment_2563',
#        'Texture_Organoid_Mito_DifferenceEntropy_2563',
#        'Texture_Organoid_Mito_DifferenceVariance_2563',
#        'Texture_Organoid_Mito_Entropy_2563',
#        'Texture_Organoid_Mito_InformationMeasureofCorrelation2_2563',
#        'Texture_Organoid_Mito_InverseDifferenceMoment_2563',
#        'Texture_Organoid_Mito_SumEntropy_2563',
#        'Colocalization_Organoid_DNAAGP_MEANMANDERSCOEFFM1',
#        'Colocalization_Organoid_DNAAGP_MEDIANMANDERSCOEFFM1',
#        'Colocalization_Organoid_DNAAGP_MINMANDERSCOEFFM1',
#        'Colocalization_Organoid_DNAAGP_MAXMANDERSCOEFFM1',
#        'Colocalization_Organoid_DNAMito_MEANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAMito_MEDIANMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAMito_MINMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_DNAMito_MAXMANDERSCOEFFCOSTESM1',
#        'Colocalization_Organoid_AGPMito_MEANMANDERSCOEFFM2',
#        'Colocalization_Organoid_AGPMito_MEDIANMANDERSCOEFFM2',
#        'Colocalization_Organoid_AGPMito_MINMANDERSCOEFFM2',
#        'Colocalization_Organoid_AGPMito_MAXMANDERSCOEFFM2',
#        'Intensity_Organoid_AGP_MAXINTENSITYEDGE',
#        'Intensity_Organoid_Mito_MADINTENSITY',
#        'Intensity_Organoid_Mito_STDINTENSITY',
#        'Intensity_Organoid_DNA_STDINTENSITYEDGE',
#        'Colocalization_Organoid_AGPER_MEANK2',
#        'Colocalization_Organoid_AGPER_MEDIANK2',
#        'Colocalization_Organoid_AGPER_MINK2',
#        'Colocalization_Organoid_AGPER_MAXK2',
#        'Colocalization_Organoid_DNAMito_MEANOVERLAPCOEFF',
#        'Colocalization_Organoid_DNAMito_MEDIANOVERLAPCOEFF',
#        'Colocalization_Organoid_DNAMito_MINOVERLAPCOEFF',
#        'Colocalization_Organoid_DNAMito_MAXOVERLAPCOEFF',
#        'Intensity_Organoid_AGP_CMIX',
#        'Intensity_Organoid_DNA_MADINTENSITY',
#        'Intensity_Organoid_DNA_MAXINTENSITYEDGE',
#        'Intensity_Organoid_DNA_MEANINTENSITY',
#        'Intensity_Organoid_ER_CMIZ', 'Intensity_Organoid_Mito_CMIX',
#        'Intensity_Organoid_Mito_CMIZ',
#        'Texture_Organoid_DNA_Contrast_2563',
#        'Intensity_Organoid_AGP_CMIZ',
#        'Intensity_Organoid_Mito_MEANINTENSITYEDGE',
#        'Colocalization_Organoid_AGPMito_MEANCORRELATIONCOEFF',
#        'Colocalization_Organoid_AGPMito_MEDIANCORRELATIONCOEFF',
#        'Colocalization_Organoid_AGPMito_MINCORRELATIONCOEFF',
#        'Colocalization_Organoid_AGPMito_MAXCORRELATIONCOEFF',
#        'Colocalization_Organoid_AGPER_MEANMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPER_MEDIANMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPER_MINMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPER_MAXMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPMito_MEANMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPMito_MEDIANMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPMito_MINMANDERSCOEFFCOSTESM2',
#        'Colocalization_Organoid_AGPMito_MAXMANDERSCOEFFCOSTESM2',
#        'Granularity_Organoid_AGP_GRANULARITY13',
#        'Granularity_Organoid_AGP_GRANULARITY14',
#        'Granularity_Organoid_AGP_GRANULARITY15',
#        'Granularity_Organoid_AGP_GRANULARITY16',
#        'Granularity_Organoid_DNA_GRANULARITY16',
#        'Granularity_Organoid_ER_GRANULARITY13',
#        'Granularity_Organoid_ER_GRANULARITY14',
#        'Granularity_Organoid_ER_GRANULARITY15',
#        'Granularity_Organoid_ER_GRANULARITY16',
#        'Granularity_Organoid_Mito_GRANULARITY13',
#        'Granularity_Organoid_Mito_GRANULARITY14',
#        'Granularity_Organoid_Mito_GRANULARITY15',
#        'Granularity_Organoid_Mito_GRANULARITY16',
#        'Texture_Organoid_ER_SumVariance_2563',
#        'Texture_Organoid_ER_Variance_2563',
#        'Colocalization_Organoid_DNAAGP_MEANMANDERSCOEFFM2',
#        'Colocalization_Organoid_DNAAGP_MEDIANMANDERSCOEFFM2',
#        'Colocalization_Organoid_DNAAGP_MINMANDERSCOEFFM2',
#        'Colocalization_Organoid_DNAAGP_MAXMANDERSCOEFFM2',
#        'AreaSizeShape_Organoid_CENTERX', 'Intensity_Organoid_AGP_CMX',
#        'Intensity_Organoid_AGP_DIFFX', 'Intensity_Organoid_DNA_CMX',
#        'Intensity_Organoid_DNA_DIFFX', 'Intensity_Organoid_ER_CMX',
#        'Intensity_Organoid_ER_DIFFX', 'Intensity_Organoid_Mito_CMX',
#        'Intensity_Organoid_Mito_DIFFX',
#        'Intensity_Organoid_ER_MAXINTENSITYEDGE'], dtype=object)
