# %% [markdown]
# ## Imports

# %%
import argparse
import os
import pathlib
import sys

# import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import skimage.io as io
import tifffile
from napari.utils import nbscreenshot
from nviz.image import image_set_to_arrays
from nviz.image_meta import extract_z_slice_number_from_filename, generate_ome_xml
from nviz.view import view_ometiff_with_napari

cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd
else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break
sys.path.append(str(root_dir / "utils"))
from arg_parsing_utils import check_for_missing_args, parse_args
from notebook_init_utils import bandicoot_check, init_notebook

root_dir, in_notebook = init_notebook()

image_base_dir = bandicoot_check(
    pathlib.Path(os.path.expanduser("~/mnt/bandicoot")).resolve(), root_dir
)

sys.path.append(f"{root_dir}/utils")
from segmentation_decoupling import euclidian_2D_distance

# %%
if not in_notebook:
    args = parse_args()
    well_fov = args["well_fov"]
    patient = args["patient"]
    check_for_missing_args(
        well_fov=well_fov,
        patient=patient,
    )
else:
    print("Running in a notebook")
    patient = "NF0037_T1_CQ1"
    well_fov = "F11-1"
image_dir = pathlib.Path(
    f"{image_base_dir}/data/{patient}/zstack_images/{well_fov}/"
).resolve(strict=True)
label_dir = pathlib.Path(
    f"{image_base_dir}/data/{patient}/segmentation_masks/{well_fov}/"
).resolve(strict=True)
# Out:
# Running in a notebook

# %%
label_dir
output_path = "output.zarr"
channel_map = {
    "405": "Nuclei",
    "488": "Endoplasmic Reticulum",
    "555": "Actin, Golgi, and plasma membrane (AGP)",
    "640": "Mitochondria",
    "TRANS": "Brightfield",
}
scaling_values = [1, 0.1, 0.1]

# %%
frame_zstacks = image_set_to_arrays(
    image_dir,
    label_dir,
    channel_map=channel_map,
)

# %%
print(frame_zstacks["images"].keys())
print(frame_zstacks["labels"].keys())
# Out:
# dict_keys(['D8-4_405', 'D8-4_488', 'D8-4_555', 'D8-4_640', 'D8-4_TRANS'])
# dict_keys(['cell_mask', 'cytoplasm_mask', 'nuclei_mask', 'organoid_mask'])

# %%
images_data = []
labels_data = []
channel_names = []
label_names = []


for channel, stack in frame_zstacks["images"].items():
    dim = len(stack.shape)
    images_data.append(stack)
    channel_names.append(channel)

# Collect label data
if label_dir:
    for compartment_name, stack in frame_zstacks["labels"].items():
        if len(stack.shape) != dim:
            if len(stack.shape) == 3:
                stack = np.expand_dims(stack, axis=0)
        labels_data.append(stack)
        label_names.append(f"{compartment_name} (labels)")


# Stack the images and labels along a new axis for channels
images_data = np.stack(images_data, axis=0)
if labels_data:
    labels_data = np.stack(labels_data, axis=0)
    combined_data = np.concatenate((images_data, labels_data), axis=0)
    combined_channel_names = channel_names + label_names
else:
    combined_data = images_data
    combined_channel_names = channel_names
# Generate OME-XML metadata
ome_metadata = {
    "SizeC": combined_data.shape[0],
    "SizeZ": combined_data.shape[1],
    "SizeY": combined_data.shape[2],
    "SizeX": combined_data.shape[3],
    "PhysicalSizeX": scaling_values[2],
    "PhysicalSizeY": scaling_values[1],
    "PhysicalSizeZ": scaling_values[0],
    # note: we use 7-bit ascii compatible characters below
    # due to tifffile limitations
    "PhysicalSizeXUnit": "um",
    "PhysicalSizeYUnit": "um",
    "PhysicalSizeZUnit": "um",
    "Channel": [{"Name": name} for name in combined_channel_names],
}
ome_xml = generate_ome_xml(ome_metadata)
import tifffile as tiff

# Write the combined data to a single OME-TIFF
with tiff.TiffWriter(output_path, bigtiff=True) as tif:
    tif.write(combined_data, description=ome_xml, photometric="minisblack")

# %%
# import shutil
# shutil.rmtree(output_path, ignore_errors=True)
# nviz.image.tiff_to_ometiff(
#     image_dir=image_dir,
#     label_dir=label_dir,
#     output_path=output_path,
#     channel_map=channel_map,
#     scaling_values=scaling_values,
#     ignore=[],
# )

# %%
viewer = view_ometiff_with_napari(
    ometiff_path=output_path,
    scaling_values=scaling_values,
    headless=False,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/_qt/threads/status_checker.py:114, in StatusChecker.calculate_status(self=<napari._qt.threads.status_checker.StatusChecker object>)
#     110     return
#     112 try:
#     113     # Calculate the status change from cursor's movement
# --> 114     res = viewer._calc_status_from_cursor()
#         viewer = Viewer(camera=Camera(center=(9.0, 76.90000000000002, 76.95000000000002), zoom=8.33333333333333, angles=(-113.7440292684523, 69.30619929735475, 1.3189468748748137), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(0.0, -3.196074331193339, 80.88795623513342, 78.34998716394749), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'D8-4_405' at 0x7f2898086ad0>, <Image layer 'D8-4_488' at 0x7f28980caa10>, <Image layer 'D8-4_555' at 0x7f290f4fee10>, <Image layer 'D8-4_TRANS' at 0x7f2890129550>, <Labels layer 'cell_mask (labels)' at 0x7f287c07e850>, <Image layer 'D8-4_640' at 0x7f2890028e50>, <Labels layer 'cytoplasm_mask (labels)' at 0x7f28900f7410>, <Labels layer 'nuclei_mask (labels)' at 0x7f283c1dd0d0>, <Labels layer 'organoid_mask (labels)' at 0x7f283c2b3810>], help='use <2> for transform', status={'layer_name': 'D8-4_488', 'layer_base': 'D8-4_488', 'source_type': '', 'plugin': '', 'coordinates': ' [0 0 51 67]: 514'}, tooltip=Tooltip(visible=True, text=''), theme='dark', title='napari', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x7f2930042480>], mouse_wheel_callbacks=[<function dims_scroll at 0x7f29300423e0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#     115 except Exception as e:  # pragma: no cover # noqa: BLE001
#     116     # Our codebase is not threadsafe. It is possible that an
#     117     # ViewerModel or Layer state is changed while we are trying to
#    (...)
#     120     # from crashing the thread. The exception is logged
#     121     # and a notification is sent.
#     122     notification_manager.dispatch(Notification.from_exception(e))
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/components/viewer_model.py:573, in ViewerModel._calc_status_from_cursor(self=Viewer(camera=Camera(center=(9.0, 76.90000000000...use_drag_gen={}, _mouse_wheel_gen={}, _keymap={}))
#     571 active = self.layers.selection.active
#     572 if active is not None and active._loaded:
# --> 573     status = active.get_status(
#         active = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         self = Viewer(camera=Camera(center=(9.0, 76.90000000000002, 76.95000000000002), zoom=8.33333333333333, angles=(-113.7440292684523, 69.30619929735475, 1.3189468748748137), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(0.0, -3.196074331193339, 80.88795623513342, 78.34998716394749), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'D8-4_405' at 0x7f2898086ad0>, <Image layer 'D8-4_488' at 0x7f28980caa10>, <Image layer 'D8-4_555' at 0x7f290f4fee10>, <Image layer 'D8-4_TRANS' at 0x7f2890129550>, <Labels layer 'cell_mask (labels)' at 0x7f287c07e850>, <Image layer 'D8-4_640' at 0x7f2890028e50>, <Labels layer 'cytoplasm_mask (labels)' at 0x7f28900f7410>, <Labels layer 'nuclei_mask (labels)' at 0x7f283c1dd0d0>, <Labels layer 'organoid_mask (labels)' at 0x7f283c2b3810>], help='use <2> for transform', status={'layer_name': 'D8-4_488', 'layer_base': 'D8-4_488', 'source_type': '', 'plugin': '', 'coordinates': ' [0 0 51 67]: 514'}, tooltip=Tooltip(visible=True, text=''), theme='dark', title='napari', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x7f2930042480>], mouse_wheel_callbacks=[<function dims_scroll at 0x7f29300423e0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#         self.cursor.position = (0.0, -3.196074331193339, 80.88795623513342, 78.34998716394749)
#         self.cursor = Cursor(position=(0.0, -3.196074331193339, 80.88795623513342, 78.34998716394749), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0)
#         self.cursor._view_direction = array([ 0.     ,  0.00813,  0.35328, -0.93548])
#         self.dims = Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0)
#     574         self.cursor.position,
#     575         view_direction=self.cursor._view_direction,
#     576         dims_displayed=list(self.dims.displayed),
#     577         world=True,
#     578     )
#     580     if self.tooltip.visible:
#     581         tooltip_text = active._get_tooltip_text(
#     582             np.asarray(self.cursor.position),
#     583             view_direction=np.asarray(self.cursor._view_direction),
#     584             dims_displayed=list(self.dims.displayed),
#     585             world=True,
#     586         )
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:2212, in Layer.get_status(self=<Image layer 'D8-4_488'>, position=array([ 0.     , -0.07206, 51.52859, 67.28974]), view_direction=array([ 0.     ,  0.00813,  0.35328, -0.93548]), dims_displayed=[1, 2, 3], world=True)
#    2210 if position is not None:
#    2211     position = np.asarray(position)
# -> 2212     value = self.get_value(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([ 0.     , -0.07206, 51.52859, 67.28974])
#         view_direction = array([ 0.     ,  0.00813,  0.35328, -0.93548])
#         dims_displayed = [1, 2, 3]
#         world = True
#    2213         position,
#    2214         view_direction=view_direction,
#    2215         dims_displayed=dims_displayed,
#    2216         world=world,
#    2217     )
#    2218 else:
#    2219     value = None
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:1427, in Layer.get_value(self=<Image layer 'D8-4_488'>, position=array([ 0.00000e+00, -7.20590e-02,  5.15286e+02,  6.72897e+02]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], world=True)
#    1425     elif len(dims_displayed) == 3:
#    1426         view_direction = self._world_to_data_ray(view_direction)
# -> 1427         start_point, end_point = self.get_ray_intersections(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([ 0.00000e+00, -7.20590e-02,  5.15286e+02,  6.72897e+02])
#         view_direction = array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01])
#         dims_displayed = [1, 2, 3]
#    1428             position=position,
#    1429             view_direction=view_direction,
#    1430             dims_displayed=dims_displayed,
#    1431             world=False,
#    1432         )
#    1433         value = self._get_value_3d(
#    1434             start_point=start_point,
#    1435             end_point=end_point,
#    1436             dims_displayed=dims_displayed,
#    1437         )
#    1438 else:
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:1944, in Layer.get_ray_intersections(self=<Image layer 'D8-4_488'>, position=array([ 0.00000e+00, -7.20590e-02,  5.15286e+02,  6.72897e+02]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], world=False)
#    1941 # bounding box is with upper limit excluded in the uses below
#    1942 bounding_box[:, 1] += 1
# -> 1944 start_point, end_point = self._get_ray_intersections(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([ 0.00000e+00, -7.20590e-02,  5.15286e+02,  6.72897e+02])
#         view_direction = array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01])
#         dims_displayed = [1, 2, 3]
#         world = False
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#    1945     position=position,
#    1946     view_direction=view_direction,
#    1947     dims_displayed=dims_displayed,
#    1948     world=world,
#    1949     bounding_box=bounding_box,
#    1950 )
#    1951 return start_point, end_point
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:2024, in Layer._get_ray_intersections(self=<Image layer 'D8-4_488'>, position=array([5.00000e-01, 4.27941e-01, 5.15786e+02, 6.73397e+02]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), world=False)
#    2020     return None, None
#    2022 # Calculate ray-bounding box face intersections
#    2023 start_point_displayed_dimensions = (
# -> 2024     intersect_line_with_axis_aligned_bounding_box_3d(
#         view_dir = array([ 8.13420e-04,  3.53292e-01, -9.35513e-01])
#         click_pos_data = array([4.27941e-01, 5.15786e+02, 6.73397e+02])
#         front_face_normal = None
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#    2025         click_pos_data, view_dir, bounding_box, front_face_normal
#    2026     )
#    2027 )
#    2028 end_point_displayed_dimensions = (
#    2029     intersect_line_with_axis_aligned_bounding_box_3d(
#    2030         click_pos_data, view_dir, bounding_box, back_face_normal
#    2031     )
#    2032 )
#    2034 # add the coordinates for the axes not displayed
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/utils/geometry.py:739, in intersect_line_with_axis_aligned_bounding_box_3d(line_point=array([4.27941e-01, 5.15786e+02, 6.73397e+02]), line_direction=array([ 8.13420e-04,  3.53292e-01, -9.35513e-01]), bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), face_normal=None)
#     709 def intersect_line_with_axis_aligned_bounding_box_3d(
#     710     line_point: np.ndarray,
#     711     line_direction: np.ndarray,
#     712     bounding_box: np.ndarray,
#     713     face_normal: np.ndarray,
#     714 ):
#     715     """Find the intersection of a ray with the specified face of an
#     716     axis-aligned bounding box.
#     717
#    (...)
#     737         the specified face.
#     738     """
# --> 739     front_face_coordinate = face_coordinate_from_bounding_box(
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#         face_normal = None
#     740         bounding_box, face_normal
#     741     )
#     742     intersection_point = np.squeeze(
#     743         intersect_line_with_axis_aligned_plane(
#     744             front_face_coordinate,
#    (...)
#     748         )
#     749     )
#     751     return intersection_point
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/utils/geometry.py:241, in face_coordinate_from_bounding_box(bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), face_normal=None)
#     220 """Get the coordinate for a given face in an axis-aligned bounding box.
#     221 For example, if the bounding box has extents [[0, 10], [0, 20], [0, 30]]
#     222 (ordered zyx), then the face with normal [0, 1, 0] is described by
#    (...)
#     238     the axis its normal is aligned with.
#     239 """
#     240 axis = np.argwhere(face_normal)
# --> 241 if face_normal[axis] > 0:
#         axis = array([], shape=(0, 0), dtype=int64)
#         face_normal = None
#     242     # face is pointing in the positive direction,
#     243     # take the max extent
#     244     face_coordinate = bounding_box[axis, 1]
#     245 else:
#     246     # face is pointing in the negative direction,
#     247     # take the min extent
#
# TypeError: 'NoneType' object is not subscriptable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/_qt/threads/status_checker.py:114, in StatusChecker.calculate_status(self=<napari._qt.threads.status_checker.StatusChecker object>)
#     110     return
#     112 try:
#     113     # Calculate the status change from cursor's movement
# --> 114     res = viewer._calc_status_from_cursor()
#         viewer = Viewer(camera=Camera(center=(9.0, 76.90000000000002, 76.95000000000002), zoom=8.33333333333333, angles=(-113.7440292684523, 69.30619929735475, 1.3189468748748137), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(0.0, 3.984287136863549, 75.88036122639633, 76.52132758097322), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'D8-4_405' at 0x7f2898086ad0>, <Image layer 'D8-4_488' at 0x7f28980caa10>, <Image layer 'D8-4_555' at 0x7f290f4fee10>, <Image layer 'D8-4_TRANS' at 0x7f2890129550>, <Labels layer 'cell_mask (labels)' at 0x7f287c07e850>, <Image layer 'D8-4_640' at 0x7f2890028e50>, <Labels layer 'cytoplasm_mask (labels)' at 0x7f28900f7410>, <Labels layer 'nuclei_mask (labels)' at 0x7f283c1dd0d0>, <Labels layer 'organoid_mask (labels)' at 0x7f283c2b3810>], help='use <2> for transform', status={'layer_name': 'D8-4_488', 'layer_base': 'D8-4_488', 'source_type': '', 'plugin': '', 'coordinates': ' [0 0 51 67]: 514'}, tooltip=Tooltip(visible=True, text=''), theme='dark', title='napari', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x7f2930042480>], mouse_wheel_callbacks=[<function dims_scroll at 0x7f29300423e0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#     115 except Exception as e:  # pragma: no cover # noqa: BLE001
#     116     # Our codebase is not threadsafe. It is possible that an
#     117     # ViewerModel or Layer state is changed while we are trying to
#    (...)
#     120     # from crashing the thread. The exception is logged
#     121     # and a notification is sent.
#     122     notification_manager.dispatch(Notification.from_exception(e))
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/components/viewer_model.py:573, in ViewerModel._calc_status_from_cursor(self=Viewer(camera=Camera(center=(9.0, 76.90000000000...use_drag_gen={}, _mouse_wheel_gen={}, _keymap={}))
#     571 active = self.layers.selection.active
#     572 if active is not None and active._loaded:
# --> 573     status = active.get_status(
#         active = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         self = Viewer(camera=Camera(center=(9.0, 76.90000000000002, 76.95000000000002), zoom=8.33333333333333, angles=(-113.7440292684523, 69.30619929735475, 1.3189468748748137), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(0.0, 3.984287136863549, 75.88036122639633, 76.52132758097322), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'D8-4_405' at 0x7f2898086ad0>, <Image layer 'D8-4_488' at 0x7f28980caa10>, <Image layer 'D8-4_555' at 0x7f290f4fee10>, <Image layer 'D8-4_TRANS' at 0x7f2890129550>, <Labels layer 'cell_mask (labels)' at 0x7f287c07e850>, <Image layer 'D8-4_640' at 0x7f2890028e50>, <Labels layer 'cytoplasm_mask (labels)' at 0x7f28900f7410>, <Labels layer 'nuclei_mask (labels)' at 0x7f283c1dd0d0>, <Labels layer 'organoid_mask (labels)' at 0x7f283c2b3810>], help='use <2> for transform', status={'layer_name': 'D8-4_488', 'layer_base': 'D8-4_488', 'source_type': '', 'plugin': '', 'coordinates': ' [0 0 51 67]: 514'}, tooltip=Tooltip(visible=True, text=''), theme='dark', title='napari', mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[<function double_click_to_zoom at 0x7f2930042480>], mouse_wheel_callbacks=[<function dims_scroll at 0x7f29300423e0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#         self.cursor.position = (0.0, 3.984287136863549, 75.88036122639633, 76.52132758097322)
#         self.cursor = Cursor(position=(0.0, 3.984287136863549, 75.88036122639633, 76.52132758097322), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0)
#         self.cursor._view_direction = array([ 0.     ,  0.00813,  0.35328, -0.93548])
#         self.dims = Dims(ndim=4, ndisplay=3, order=(0, 1, 2, 3), axis_labels=('0', '1', '2', '3'), rollable=(True, True, True, True), range=(RangeTuple(start=0.0, stop=0.0, step=1.0), RangeTuple(start=0.0, stop=18.0, step=1.0), RangeTuple(start=0.0, stop=153.8, step=0.1), RangeTuple(start=0.0, stop=153.9, step=0.1)), margin_left=(0.0, 0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0, 0.0), point=(0.0, 17.0, 76.9, 76.9), last_used=0)
#     574         self.cursor.position,
#     575         view_direction=self.cursor._view_direction,
#     576         dims_displayed=list(self.dims.displayed),
#     577         world=True,
#     578     )
#     580     if self.tooltip.visible:
#     581         tooltip_text = active._get_tooltip_text(
#     582             np.asarray(self.cursor.position),
#     583             view_direction=np.asarray(self.cursor._view_direction),
#     584             dims_displayed=list(self.dims.displayed),
#     585             world=True,
#     586         )
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:2212, in Layer.get_status(self=<Image layer 'D8-4_488'>, position=array([ 0.     , -0.98481, 80.53713, 78.23673]), view_direction=array([ 0.     ,  0.00813,  0.35328, -0.93548]), dims_displayed=[1, 2, 3], world=True)
#    2210 if position is not None:
#    2211     position = np.asarray(position)
# -> 2212     value = self.get_value(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([ 0.     , -0.98481, 80.53713, 78.23673])
#         view_direction = array([ 0.     ,  0.00813,  0.35328, -0.93548])
#         dims_displayed = [1, 2, 3]
#         world = True
#    2213         position,
#    2214         view_direction=view_direction,
#    2215         dims_displayed=dims_displayed,
#    2216         world=world,
#    2217     )
#    2218 else:
#    2219     value = None
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:1427, in Layer.get_value(self=<Image layer 'D8-4_488'>, position=array([  0.     ,  -0.98481, 805.37129, 782.36726]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], world=True)
#    1425     elif len(dims_displayed) == 3:
#    1426         view_direction = self._world_to_data_ray(view_direction)
# -> 1427         start_point, end_point = self.get_ray_intersections(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([  0.     ,  -0.98481, 805.37129, 782.36726])
#         view_direction = array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01])
#         dims_displayed = [1, 2, 3]
#    1428             position=position,
#    1429             view_direction=view_direction,
#    1430             dims_displayed=dims_displayed,
#    1431             world=False,
#    1432         )
#    1433         value = self._get_value_3d(
#    1434             start_point=start_point,
#    1435             end_point=end_point,
#    1436             dims_displayed=dims_displayed,
#    1437         )
#    1438 else:
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:1944, in Layer.get_ray_intersections(self=<Image layer 'D8-4_488'>, position=array([  0.     ,  -0.98481, 805.37129, 782.36726]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], world=False)
#    1941 # bounding box is with upper limit excluded in the uses below
#    1942 bounding_box[:, 1] += 1
# -> 1944 start_point, end_point = self._get_ray_intersections(
#         self = <Image layer 'D8-4_488' at 0x7f28980caa10>
#         position = array([  0.     ,  -0.98481, 805.37129, 782.36726])
#         view_direction = array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01])
#         dims_displayed = [1, 2, 3]
#         world = False
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#    1945     position=position,
#    1946     view_direction=view_direction,
#    1947     dims_displayed=dims_displayed,
#    1948     world=world,
#    1949     bounding_box=bounding_box,
#    1950 )
#    1951 return start_point, end_point
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/layers/base/base.py:2024, in Layer._get_ray_intersections(self=<Image layer 'D8-4_488'>, position=array([ 5.00000e-01, -4.84810e-01,  8.05871e+02,  7.82867e+02]), view_direction=array([ 0.00000e+00,  8.13420e-04,  3.53292e-01, -9.35513e-01]), dims_displayed=[1, 2, 3], bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), world=False)
#    2020     return None, None
#    2022 # Calculate ray-bounding box face intersections
#    2023 start_point_displayed_dimensions = (
# -> 2024     intersect_line_with_axis_aligned_bounding_box_3d(
#         view_dir = array([ 8.13420e-04,  3.53292e-01, -9.35513e-01])
#         click_pos_data = array([-4.84810e-01,  8.05871e+02,  7.82867e+02])
#         front_face_normal = None
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#    2025         click_pos_data, view_dir, bounding_box, front_face_normal
#    2026     )
#    2027 )
#    2028 end_point_displayed_dimensions = (
#    2029     intersect_line_with_axis_aligned_bounding_box_3d(
#    2030         click_pos_data, view_dir, bounding_box, back_face_normal
#    2031     )
#    2032 )
#    2034 # add the coordinates for the axes not displayed
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/utils/geometry.py:739, in intersect_line_with_axis_aligned_bounding_box_3d(line_point=array([-4.84810e-01,  8.05871e+02,  7.82867e+02]), line_direction=array([ 8.13420e-04,  3.53292e-01, -9.35513e-01]), bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), face_normal=None)
#     709 def intersect_line_with_axis_aligned_bounding_box_3d(
#     710     line_point: np.ndarray,
#     711     line_direction: np.ndarray,
#     712     bounding_box: np.ndarray,
#     713     face_normal: np.ndarray,
#     714 ):
#     715     """Find the intersection of a ray with the specified face of an
#     716     axis-aligned bounding box.
#     717
#    (...)
#     737         the specified face.
#     738     """
# --> 739     front_face_coordinate = face_coordinate_from_bounding_box(
#         bounding_box = array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]])
#         face_normal = None
#     740         bounding_box, face_normal
#     741     )
#     742     intersection_point = np.squeeze(
#     743         intersect_line_with_axis_aligned_plane(
#     744             front_face_coordinate,
#    (...)
#     748         )
#     749     )
#     751     return intersection_point
#
# File ~/miniforge3/envs/viz_env/lib/python3.11/site-packages/napari/utils/geometry.py:241, in face_coordinate_from_bounding_box(bounding_box=array([[   0.,   19.],
#        [   0., 1539.],
#        [   0., 1540.]]), face_normal=None)
#     220 """Get the coordinate for a given face in an axis-aligned bounding box.
#     221 For example, if the bounding box has extents [[0, 10], [0, 20], [0, 30]]
#     222 (ordered zyx), then the face with normal [0, 1, 0] is described by
#    (...)
#     238     the axis its normal is aligned with.
#     239 """
#     240 axis = np.argwhere(face_normal)
# --> 241 if face_normal[axis] > 0:
#         axis = array([], shape=(0, 0), dtype=int64)
#         face_normal = None
#     242     # face is pointing in the positive direction,
#     243     # take the max extent
#     244     face_coordinate = bounding_box[axis, 1]
#     245 else:
#     246     # face is pointing in the negative direction,
#     247     # take the min extent
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# toggle view for all labels except organoid
for layer in viewer.layers:
    if "organoid" not in layer.name.lower():
        layer.visible = False

# %%
# screenshot the napari viewer
nbscreenshot(viewer)
